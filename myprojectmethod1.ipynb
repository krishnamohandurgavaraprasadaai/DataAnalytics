# %%
import numpynumpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
df=pd.read_csv("/content/DoctorVisits.csv")

# %%
a2=[i/100 for i in range(19,37)]

# %%
a3=[i/100 for i in range(37,55)]

# %%
a4=[i/100 for i in range(55,75)]

# %%
age2=df[df['age'].isin(a2)]

# %%
age3=df[df['age'].isin(a3)]

# %%
age4=df[df['age'].isin(a4)]

# %%
ag2=sum(age2['visits'])

# %%
ag3=sum(age3['visits'])

# %%
ag4=sum(age4['visits'])

# %%
ages=['<37','37&55','55&75']

# %%
visit=[ag2,ag3,ag4]

# %%
plt.subplot(1,3,1)
# Out:
# <Axes: >

# %%
plt.bar(ages,visit,color='green')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.pie([ag2,ag3,ag4],labels=['less 37','inb/w 37&55','inb/w 55&75'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7881033ff220>,
# ...
#  [Text(0.3699944440503063, 1.035907385518563, 'less 37'),
#   Text(-1.065594959679613, 0.27296040354858087, 'inb/w 37&55'),
#   Text(0.10136587299654054, -1.0953195697108902, 'inb/w 55&75')])

# %%
plt.show()
